# %%
#calculator
num1=int(input("enter 1st num:"))
num2=int(input("enter 2nd num:"))
def add(x,y):
    return(x+y)
def substrct(x,y):
    return(x-y)
def multiply(x,y):
    return(x*y)
def divide(x,y):
    return(x/y)
print("select opretions:")
print("1.add")
print("2.substrct")
print("3.multiply")
print("4.divide")
choice=input("enter choice (1/2/3/4):")
if choice=='1':
    print("Result:",add(num1,num2))
elif choice=='2':
    print("Result:",substrct(num1,num2))
elif choice=='3':
    print("Result:",multiply(num1,num2))
elif choice=='4':
    print("Result:",divide(num1,num2))
else:
    print("invalid input")
# Out:
# select opretions:
# 1.add
# 2.substrct
# 3.multiply
# 4.divide
# Result: 15

# %%
#discount calculate by method1
amount=int(input("enter orignal price:"))
if amount<=10000:
           discount=amount*0.08
if amount>=5000:
           discount=amount*0.20
else:
  discountiscount=amount*0.30
final_price=amount-discount
print("discount amount:",discount)
print("final price:",final_price)
# Out:
# discount amount: 320.0
# final price: 3680.0

# %%
#calculate discout by method2
price=int(input("enter org. price:"))
discount_prcent=float(input("enter discount percentage:"))
discount_amount=(price*discount_prcent)/100
final_price=price-discount_amount
print("discount amount:",discount_amount)
print("final price after discount:",final_price)
# Out:
# discount amount: 800.0
# final price after discount: 3200.0
