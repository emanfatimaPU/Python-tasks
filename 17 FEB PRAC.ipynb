# %%
str1="Hellow"
str2="word"
result_conc="str1+" "str2"
print(str1+str2)

##length



str1="Hellow"
str2="word"
result_conc="str1+" "str2"
print (len(str1+str2))

##append

Mylist=[1,2,3,4,5]
Mylist.append(4)
print(Mylist)

##slice
str1="Hellow"
str2="word"
print(str1[0:5])
print(str2[0:2])

##UPPER

str1="hellow"
str2="word"
print("str1.upper")
print("str2.upper")

#LOWER
str1="hellow"
str2="word"
print("str1.per")
print("str2.upper")
##INDUX

mylist=[1,2,3,4,5]
index=mylist.index(2)
print(index)

#REPLce
str="eman"
str1=str.replace("e","m")
print(str1)


#remove

str="eman"
str1=str.removesuffix("h")
print(str1)


#add
x=1
y=3
x+y
print(x+y)
# Out:
# Hellowword
# 10
# [1, 2, 3, 4, 5, 4]
# Hello
# wo
# str1.upper
# str2.upper
# str1.per
# str2.upper
# 1
# mman
# eman
# 4
