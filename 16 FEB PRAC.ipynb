# %%
a=10
b=20
c=30
d=40
e=50
print(a,b,c,d,e)

a=3.3
b=3.6
c=7.6
d=5.1
e=3.2
print(a,b,c,d,e)
chr1= "aki"
chr2="Eman"
chr3="fatima"
chr4="habiba"
chr5="hajra"
print(chr1)
print(chr2)
print(chr3)
print(chr4)
print(chr5)
# Out:
# 10 20 30 40 50
# 3.3 3.6 7.6 5.1 3.2
# aki
# Eman
# fatima
# habiba
# hajra
